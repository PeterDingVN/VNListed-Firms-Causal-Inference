# %% [markdown]
# Library

# %%
from sklearn.metrics import classification_report
from src.utils import *
from src.training.normal_ml import *

# %% [markdown]
# Data

# %%
df_ebitda = pd.read_csv('../../data/data_for_modelling/df_ebitda.csv')
ebitda_input, ebitda_test = input_test_split(df_ebitda)

# %% [markdown]
# Modelling

# %%
# Best param choice
ebitda_obj = InputData(ebitda_input, 'company', 'year', 'ebitda', reg=False)
display(ebitda_obj.optimal_param(n_splits=3, test_size=2))
# Out:
# Processing XG_class ...
# Processing KNN_class ...
#     algo_used                                             params  \
# 0    XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 1    XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 20   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 25   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 5    XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 26   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 30   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 10   XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 2    XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 21   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 6    XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 31   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 35   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 36   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 11   XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 15   XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 32   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 27   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 22   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 37   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 7    XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 12   XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 16   XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 23   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 33   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 3    XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 17   XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 13   XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 28   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 8    XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 38   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 18   XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 4    XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 29   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 24   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 34   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 9    XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 39   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 14   XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 19   XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 46  KNN_class  {'algo__n_neighbors': 7, 'algo__weights': 'uni...
# 48  KNN_class  {'algo__n_neighbors': 9, 'algo__weights': 'uni...
# 49  KNN_class  {'algo__n_neighbors': 9, 'algo__weights': 'dis...
# 47  KNN_class  {'algo__n_neighbors': 7, 'algo__weights': 'dis...
# 44  KNN_class  {'algo__n_neighbors': 5, 'algo__weights': 'uni...
# 45  KNN_class  {'algo__n_neighbors': 5, 'algo__weights': 'dis...
# 42  KNN_class  {'algo__n_neighbors': 3, 'algo__weights': 'uni...
# 43  KNN_class  {'algo__n_neighbors': 3, 'algo__weights': 'dis...
# 40  KNN_class  {'algo__n_neighbors': 1, 'algo__weights': 'uni...
# 41  KNN_class  {'algo__n_neighbors': 1, 'algo__weights': 'dis...
#
#     mean_test_accuracy  mean_test_roc_auc  mean_test_precision  \
# 0             0.783938           0.783938             0.945564
# 1             0.783912           0.783912             0.942128
# 20            0.783908           0.783908             0.944955
# 25            0.782727           0.782727             0.945113
# 5             0.782140           0.782140             0.944506
# 26            0.781490           0.781490             0.941668
# 30            0.781264           0.781264             0.942863
# 10            0.781235           0.781235             0.942697
# 2             0.780961           0.780961             0.940148
# 21            0.780534           0.780534             0.940775
# 6             0.780320           0.780320             0.941409
# 31            0.780107           0.780107             0.940125
# 35            0.779795           0.779795             0.942169
# 36            0.779261           0.779261             0.940028
# 11            0.779141           0.779141             0.939993
# 15            0.778915           0.778915             0.941317
# 32            0.777142           0.777142             0.938263
# 27            0.775324           0.775324             0.938521
# 22            0.775240           0.775240             0.937977
# 37            0.774499           0.774499             0.937668
# 7             0.773573           0.773573             0.938008
# 12            0.773537           0.773537             0.937419
# 16            0.772918           0.772918             0.937848
# 23            0.772084           0.772084             0.936299
# 33            0.767722           0.767722             0.934820
# 3             0.767094           0.767094             0.935034
# 17            0.765352           0.765352             0.934695
# 13            0.763907           0.763907             0.933783
# 28            0.761180           0.761180             0.933504
# 8             0.760361           0.760361             0.933058
# 38            0.758914           0.758914             0.932219
# 18            0.749402           0.749402             0.929093
# 4             0.747800           0.747800             0.928971
# 29            0.745411           0.745411             0.928447
# 24            0.745276           0.745276             0.928254
# 34            0.741542           0.741542             0.926905
# 9             0.736197           0.736197             0.925636
# 39            0.734702           0.734702             0.924668
# 14            0.732764           0.732764             0.924301
# 19            0.721085           0.721085             0.920482
# 46            0.719701           0.719701             0.919685
# 48            0.719280           0.719280             0.919758
# 49            0.713084           0.713084             0.918123
# 47            0.710992           0.710992             0.917407
# 44            0.709800           0.709800             0.917153
# 45            0.700742           0.700742             0.914628
# 42            0.698151           0.698151             0.914309
# 43            0.691194           0.691194             0.912448
# 40            0.665594           0.665594             0.906740
# 41            0.665594           0.665594             0.906740
#
#     mean_test_recall
# 0           0.887456
# 1           0.919981
# 20          0.893153
# 25          0.887911
# 5           0.891647
# 26          0.916560
# 30          0.901681
# 10          0.905248
# 2           0.931690
# 21          0.923588
# 6           0.916792
# 31          0.928187
# 35          0.904805
# 36          0.926462
# 11          0.926292
# 15          0.911107
# 32          0.937973
# 27          0.929561
# 22          0.935048
# 37          0.935635
# 7           0.931141
# 12          0.935304
# 16          0.928036
# 23          0.943163
# 33          0.944364
# 3           0.941891
# 17          0.938745
# 13          0.945848
# 28          0.943205
# 8           0.943904
# 38          0.947884
# 18          0.950059
# 4           0.953059
# 29          0.953496
# 24          0.953191
# 34          0.955646
# 9           0.955556
# 39          0.959541
# 14          0.958238
# 19          0.962135
# 46          0.960794
# 48          0.958663
# 49          0.958601
# 47          0.960176
# 44          0.959449
# 45          0.958809
# 42          0.956301
# 43          0.953939
# 40          0.922471
# 41          0.922471

# %%
# Main model
# Train val
X_train, y_train, X_val, y_val = train_val_split(ebitda_input, 'ebitda')
model = xgb_class(n_estimators= 300, learning_rate=0.03, max_depth=15,
                subsample=0.7, scale_pos_weight= 0.15134
                  )

model.fit(X_train, y_train)
y_pred = model.predict(X_val)


print('----------- TRAIN RESULTS -----------')
print(f'Accuracy: {accuracy(y_val, y_pred)}')
print(f'Precision: {precision(y_val, y_pred)}')
print(f'Recall: {recall(y_val, y_pred)}')
print(f'ROC_AUC: {roc_auc(y_val, y_pred)}')
# Test
print('----------- TEST RESULTS -----------')
X_test = ebitda_test.drop(['company', 'ebitda', 'year'], axis=1)
y_test = ebitda_test['ebitda']
y_pred_test = model.predict(X_test)
print(f'Accuracy: {accuracy(y_test, y_pred_test)}')
print(f'Precision: {precision(y_test, y_pred_test)}')
print(f'Recall: {recall(y_test, y_pred_test)}')
print(f'ROC_AUC: {roc_auc(y_test, y_pred_test)}')

print(classification_report(y_val, y_pred, digits=3))
# Out:
# ----------- TRAIN RESULTS -----------
# Accuracy: 0.7755108947721574
# Precision: 0.9224334600760457
# Recall: 0.9388544891640866
# ROC_AUC: 0.7755108947721574
# ----------- TEST RESULTS -----------
# Accuracy: 0.8120315693845106
# Precision: 0.9535452322738386
# Recall: 0.9034749034749034
# ROC_AUC: 0.8120315693845105
#               precision    recall  f1-score   support
#
#            0      0.671     0.612     0.640       263
#            1      0.922     0.939     0.931      1292
#
#     accuracy                          0.884      1555
#    macro avg      0.797     0.776     0.785      1555
# weighted avg      0.880     0.884     0.881      1555

# %%
df_ebitda['ebitda'].value_counts()
# Out:
# ebitda
# 1    12799
# 0     1945
# Name: count, dtype: int64

# %% [markdown]
# Conclusion:
# - Balanced accuracy, precision, recall of val and test set are consistent and fairly high
# - But, The performance of class no.1 is way more superior in terms of recall, precision
# - However, this is due to class imbalance of 1:7 for class 0:1
# - Therefore, this result for class 0 is not bad but acceptable

# %% [markdown]
# Best param:
# - XGBoostRegressor:
#     + n_estimator = 300
#     + learning_rate = 0.03
#     + max_depth = 15
#     + subsample = 0.7
#     + scale_pos_weight = 0.15134
