# %%
from src.data_clean.raw_cleaner import *
from functools import reduce

df1 = prep_scraped_data(r'C:\Users\HP\.0_PycharmProjects\Vnlisted_causal\data\FiinProX_DE_Doanh_nghiep_20260120 (12).xlsx')
df2 = prep_scraped_data(r'C:\Users\HP\.0_PycharmProjects\Vnlisted_causal\data\FiinProX_DE_Doanh_nghiep_20260120 (11).xlsx')
df3 = prep_scraped_data(r'C:\Users\HP\.0_PycharmProjects\Vnlisted_causal\data\FiinProX_DE_Doanh_nghiep_20260120 (10).xlsx')
df4 = prep_scraped_data(r'C:\Users\HP\.0_PycharmProjects\Vnlisted_causal\data\FiinProX_DE_Doanh_nghiep_20260120 (9).xlsx')
df5 = prep_scraped_data(r'C:\Users\HP\.0_PycharmProjects\Vnlisted_causal\data\FiinProX_DE_Doanh_nghiep_20260120 (8).xlsx')
df6 = prep_scraped_data(r'C:\Users\HP\.0_PycharmProjects\Vnlisted_causal\data\FiinProX_DE_Doanh_nghiep_20260120 (7).xlsx')
df7= prep_scraped_data(r'C:\Users\HP\.0_PycharmProjects\Vnlisted_causal\data\FiinProX_DE_Doanh_nghiep_20260120 (6).xlsx')
df8 = prep_scraped_data(r'C:\Users\HP\.0_PycharmProjects\Vnlisted_causal\data\FiinProX_DE_Doanh_nghiep_20260120 (5).xlsx')
df9 = prep_scraped_data(r'C:\Users\HP\.0_PycharmProjects\Vnlisted_causal\data\cash_flow_FCF_(OPTIONAL).xlsx')

dfs = [df1, df2, df3, df4, df5, df6, df7, df8, df9]
main_df = reduce(lambda x, y: pd.merge(x, y, on=['Mã', 'date'], how='outer'), dfs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 4
#       1 from src.data_clean.raw_cleaner import *
#       2 from functools import reduce
# ----> 4 df1 = prep_scraped_data(r'C:\Users\HP\.0_PycharmProjects\Vnlisted_causal\data\FiinProX_DE_Doanh_nghiep_20260120 (12).xlsx')
#       5 df2 = prep_scraped_data(r'C:\Users\HP\.0_PycharmProjects\Vnlisted_causal\data\FiinProX_DE_Doanh_nghiep_20260120 (11).xlsx')
#       6 df3 = prep_scraped_data(r'C:\Users\HP\.0_PycharmProjects\Vnlisted_causal\data\FiinProX_DE_Doanh_nghiep_20260120 (10).xlsx')
#
# File ~\.0_PycharmProjects\Vnlisted_causal\src\data_clean\raw_cleaner.py:46, in prep_scraped_data(path)
#      42 # Add date cols
#      43 df_unpivot['datetime'] = df_unpivot['variable'].apply(
#      44   lambda x: re.search( r'Q[1-4]\.\d{4}', x).group()
#      45 )
# ...

# %%
import pandas as pd
pd.read_excel(r'C:\Users\HP\.0_PycharmProjects\Vnlisted_causal\data\FiinProX_DE_Doanh_nghiep_20260120 (7).xlsx', header=7)
# Out:
#                                       STT   Mã                   Tên công ty  \
# 0                                       1  BSR          Lọc Hóa dầu Bình Sơn
# 1                                       2  OIL                        PV Oil
# 2                                       3  PEQ  Thiết bị xăng dầu Petrolimex
# 3                                       4  PLX                    Petrolimex
# 4                                       5  POS      Vận hành và Xây lắp PTSC
# ...                                   ...  ...                           ...
# 2924        Website: https://fiingroup.vn  NaN                           NaN
# 2925                                  NaN  NaN                           NaN
# 2926        TRUNG TÂM CHĂM SÓC KHÁCH HÀNG  NaN                           NaN
# 2927    T: (84-24) - 3562 6962 - Ext: 103  NaN                           NaN
# 2928  Email: fiinpro.support@fiingroup.vn  NaN                           NaN
#
#         Sàn  \
# 0      HOSE
# 1     UPCoM
# ...
