# %% [markdown]
# Library

# %%
from sklearn.metrics import classification_report
from utils.utils_dta_processing import *
from utils.utils_ml_train import *

# %% [markdown]
# Data

# %%
df_value = pd.read_csv('../../data/data_for_modelling/df_value_ad.csv')
value_input, value_test = input_test_split(df_value)

# %% [markdown]
# Modelling

# %%
# Best param choice
value_obj = InputData(value_input, 'company', 'year', 'value_add', reg=False)
display(value_obj.optimal_param(n_splits=3, test_size=2))
# Out:
# Processing XG_class ...
# Processing KNN_class ...
#     algo_used                                             params  \
# 26   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 2    XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 27   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 32   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 22   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 1    XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 37   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 6    XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 7    XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 36   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 31   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 21   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 23   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 11   XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 16   XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 33   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 12   XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 3    XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 28   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 13   XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 17   XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 8    XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 15   XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 35   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 10   XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 38   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 24   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 30   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 20   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 34   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 4    XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 0    XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 29   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 25   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 5    XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 18   XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 9    XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 14   XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 39   XG_class  {'algo__learning_rate': 0.03, 'algo__max_depth...
# 48  KNN_class  {'algo__n_neighbors': 9, 'algo__weights': 'uni...
# 19   XG_class  {'algo__learning_rate': 0.05, 'algo__max_depth...
# 46  KNN_class  {'algo__n_neighbors': 7, 'algo__weights': 'uni...
# 49  KNN_class  {'algo__n_neighbors': 9, 'algo__weights': 'dis...
# 44  KNN_class  {'algo__n_neighbors': 5, 'algo__weights': 'uni...
# 47  KNN_class  {'algo__n_neighbors': 7, 'algo__weights': 'dis...
# 45  KNN_class  {'algo__n_neighbors': 5, 'algo__weights': 'dis...
# 42  KNN_class  {'algo__n_neighbors': 3, 'algo__weights': 'uni...
# 43  KNN_class  {'algo__n_neighbors': 3, 'algo__weights': 'dis...
# 40  KNN_class  {'algo__n_neighbors': 1, 'algo__weights': 'uni...
# 41  KNN_class  {'algo__n_neighbors': 1, 'algo__weights': 'dis...
#
#     mean_test_accuracy  mean_test_roc_auc  mean_test_precision  \
# 26            0.778344           0.778344             0.914021
# 2             0.778000           0.778000             0.912273
# 27            0.777777           0.777777             0.912127
# 32            0.777365           0.777365             0.911438
# 22            0.777364           0.777364             0.911504
# 1             0.776897           0.776897             0.913648
# 37            0.776721           0.776721             0.911467
# 6             0.776577           0.776577             0.913899
# 7             0.776490           0.776490             0.912252
# 36            0.776408           0.776408             0.912560
# 31            0.776400           0.776400             0.912379
# 21            0.776326           0.776326             0.912367
# 23            0.776230           0.776230             0.910168
# 11            0.776017           0.776017             0.912350
# 16            0.775971           0.775971             0.912632
# 33            0.775962           0.775962             0.909959
# 12            0.775357           0.775357             0.910987
# 3             0.775205           0.775205             0.909863
# 28            0.774082           0.774082             0.909429
# 13            0.773278           0.773278             0.908907
# 17            0.773243           0.773243             0.910297
# 8             0.772937           0.772937             0.909268
# 15            0.772440           0.772440             0.914537
# 35            0.772362           0.772362             0.914721
# 10            0.771000           0.771000             0.914738
# 38            0.770890           0.770890             0.907942
# 24            0.770817           0.770817             0.907330
# 30            0.770333           0.770333             0.914628
# 20            0.766179           0.766179             0.916262
# 34            0.765556           0.765556             0.904827
# 4             0.764553           0.764553             0.904762
# 0             0.764310           0.764310             0.915842
# 29            0.763900           0.763900             0.904494
# 25            0.763771           0.763771             0.915346
# 5             0.762732           0.762732             0.914446
# 18            0.760892           0.760892             0.903306
# 9             0.756089           0.756089             0.901070
# 14            0.754858           0.754858             0.900077
# 39            0.751183           0.751183             0.898579
# 48            0.738573           0.738573             0.892585
# 19            0.738015           0.738015             0.892643
# 46            0.732914           0.732914             0.890231
# 49            0.729762           0.729762             0.888847
# 44            0.720236           0.720236             0.885027
# 47            0.719563           0.719563             0.885032
# 45            0.710425           0.710425             0.881262
# 42            0.701889           0.701889             0.878073
# 43            0.697015           0.697015             0.876528
# 40            0.674762           0.674762             0.870320
# 41            0.674762           0.674762             0.870320
#
#     mean_test_recall
# 26          0.908605
# 2           0.920541
# 27          0.920445
# 32          0.924496
# 22          0.923902
# 1           0.906102
# 37          0.922125
# 6           0.903446
# 7           0.916037
# 36          0.913176
# 31          0.914936
# 21          0.913995
# 23          0.929866
# 11          0.912714
# 16          0.910495
# 33          0.930252
# 12          0.920911
# 3           0.928928
# 28          0.928909
# 13          0.929809
# 17          0.919340
# 8           0.926943
# 15          0.885837
# 35          0.884137
# 10          0.879920
# 38          0.930127
# 24          0.933912
# 30          0.877543
# 20          0.854558
# 34          0.936135
# 4           0.934764
# 0           0.851160
# 29          0.935306
# 25          0.852350
# 5           0.855323
# 18          0.932916
# 9           0.938471
# 14          0.938114
# 39          0.939974
# 48          0.945315
# 19          0.943306
# 46          0.946585
# 49          0.946362
# 44          0.945390
# 47          0.946951
# 45          0.945295
# 42          0.940592
# 43          0.937345
# 40          0.904880
# 41          0.904880

# %%
# Train val
X_train, y_train, X_val, y_val = train_val_split(value_input, 'value_add')

model = xgb_class(n_estimators= 200, learning_rate=0.02, max_depth=10,
                subsample=0.5, scale_pos_weight=0.223
                  )
model.fit(X_train, y_train)
y_pred = model.predict(X_val)


print('----------- TRAIN RESULTS -----------')
print(f'Accuracy: {accuracy(y_val, y_pred)}')
print(f'Precision: {precision(y_val, y_pred)}')
print(f'Recall: {recall(y_val, y_pred)}')
print(f'ROC_AUC: {roc_auc(y_val, y_pred)}')
# Test
print('----------- TEST RESULTS -----------')
X_test = value_test.drop(['company', 'value_add', 'year'], axis=1)
y_test = value_test['value_add']
y_pred_test = model.predict(X_test)
print(f'Accuracy: {accuracy(y_test, y_pred_test)}')
print(f'Precision: {precision(y_test, y_pred_test)}')
print(f'Recall: {recall(y_test, y_pred_test)}')
print(f'ROC_AUC: {roc_auc(y_test, y_pred_test)}')

print(classification_report(y_val, y_pred, digits=3))
# Out:
# ----------- TRAIN RESULTS -----------
# Accuracy: 0.7711450473110553
# Precision: 0.8819218241042345
# Recall: 0.9417391304347826
# ROC_AUC: 0.7711450473110553
# ----------- TEST RESULTS -----------
# Accuracy: 0.8373684860895354
# Precision: 0.9410187667560321
# Recall: 0.901541095890411
# ROC_AUC: 0.8373684860895354
#               precision    recall  f1-score   support
#
#            0      0.765     0.601     0.673       363
#            1      0.882     0.942     0.911      1150
#
#     accuracy                          0.860      1513
#    macro avg      0.823     0.771     0.792      1513
# weighted avg      0.854     0.860     0.854      1513

# %%
df_value['value_add'].value_counts()
# Out:
# value_add
# 1    11696
# 0     2639
# Name: count, dtype: int64

# %% [markdown]
# Conclusion:
# - precision and recall of both val and test set are consistent
# - precision and recall among class are close despite imbalanced class of around 1:7 for class 0 versus 1
# - Note that the balanced accuracy (accuracy) are quite high for both val and test set, signaling the effectiveness of this model

# %% [markdown]
# Best params:
# - XGBoost:
#     + n_estimators= 200
#     + learning_rate=0.02
#     + max_depth=10
#     + subsample=0.5
#     + scale_pos_weight=0.223
